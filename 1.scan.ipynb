# %%
from github import Github

# Authentication is defined via github.Auth
from github import Auth
import pandas as pd
import os

# %%
department = 'BLC'
private_token = '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'
host = "https://github.com"

# %%
auth = Auth.Token(private_token)
g = Github(auth=auth)
g.get_user().login
# Out:
# 'kongyb1032002'

# %%
info_folder = os.path.join('info', department)
os.makedirs(info_folder, exist_ok=True)  # Tạo thư mục nếu chưa tồn tại

# %%
# 1. Lấy danh sách repositories mà người dùng sở hữu
user = g.get_user()
repos = user.get_repos()

# %%
list_repos = []
for repo in repos:
    list_repos.append({
        'id': repo.id,
        'name': repo.name,
        'full_name': repo.full_name,
        'owner': repo.owner.login,
        'created_at': repo.created_at,
        'default_branch': repo.default_branch,
    })

df_repos = pd.DataFrame(list_repos)

df_repos
# Out:
#            id                    name                             full_name  \
# 0   863839707         corev4-explorer                 blcvn/corev4-explorer
# 1   884031925          lab-gitlab-api                  blcvn/lab-gitlab-api
# 2   856157805            CYB-Database                    DXL64/CYB-Database
# 3   856975972             CYB-Manager                     DXL64/CYB-Manager
# 4   877679995         Ansible_example         kongyb1032002/Ansible_example
# 5   881313813         docker-database         kongyb1032002/docker-database
# 6   881830578              GoEthExamp              kongyb1032002/GoEthExamp
# 7   828058053         go_microservice         kongyb1032002/go_microservice
# 8   876959666       HAM-Tracking-Tool       kongyb1032002/HAM-Tracking-Tool
# 9   883549550      Hyperledger-fabric      kongyb1032002/Hyperledger-fabric
# 10  884114251  hyperledger-subscriber  kongyb1032002/hyperledger-subscriber
# ...

# %%
file_repos = os.path.join(info_folder, 'repos.csv')
df_repos.to_csv(file_repos, index=False)

# %%
orgs = user.get_orgs()
list_orgs = []
for org in orgs:
    list_orgs.append({
        'id': org.id,
        'name': org.login,
        'full_name': org.name,
        'created_at': org.created_at,
    })

df_orgs = pd.DataFrame(list_orgs)
df_orgs
# Out:
#           id         name full_name                created_at
# 0  129816109  blc-onchain      None 2023-04-04 02:49:34+00:00

# %%
file_orgs = os.path.join(info_folder, 'orgs.csv')
df_orgs.to_csv(file_orgs, index=False)

# %%
list_team_members = []

for org in orgs:
    teams = org.get_teams()
    for team in teams:
        members = team.get_members()
        for member in members:
            list_team_members.append({
                'org_name': org.login,
                'team_id': team.id,
                'team_name': team.name,
                'member_id': member.id,
                'member_login': member.login,
                'member_name': member.name,
                'created_at': member.created_at,
            })

df_team_members = pd.DataFrame(list_team_members)
df_team_members
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
file_team_members = os.path.join(info_folder, 'team_members.csv')
df_team_members.to_csv(file_team_members, index=False)

# %%
list_repo_members = []

for repo in repos:
    try:
        collaborators = repo.get_collaborators()  # Lấy tất cả các cộng tác viên của repo
        for collaborator in collaborators:
            print(collaborator)
            list_repo_members.append({
                'repo_name': repo.name,
                'repo_full_name': repo.full_name,
                'member_id': collaborator.id,
                'member_login': collaborator.login,
                'member_name': collaborator.name,
                'permissions': collaborator.permissions,
                'created_at': collaborator.created_at,
            })
    except Exception as ex:
        print(f"Error fetching collaborators for {repo.full_name}: {ex}")

df_repo_members = pd.DataFrame(list_repo_members)
df_repo_members
# Out:
# NamedUser(login="nguyencongluat")
# NamedUser(login="tuandq2112")
# NamedUser(login="kongyb1032002")
# NamedUser(login="MinhPC2k3")
# Error fetching collaborators for blcvn/lab-gitlab-api: 404 {"message": "Not Found", "documentation_url": "https://docs.github.com/rest/collaborators/collaborators#list-repository-collaborators", "status": "404"}
# NamedUser(login="DXL64")
# NamedUser(login="kongyb1032002")
# NamedUser(login="trananhhh")
# NamedUser(login="DXL64")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="dnguyenx215")
# NamedUser(login="kongyb1032002")
# NamedUser(login="duynguyen1505df")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# NamedUser(login="kongyb1032002")
# ...

# %%
file_repo_members = os.path.join(info_folder, 'repo_members.csv')
df_repo_members.to_csv(file_repo_members, index=False)
