# %%
from github import Github
from github import Auth
import pprint

token= ""
auth = Auth.Token(token)
g = Github(auth=auth)

# Get user 
user = g.get_user()

# Check user 
attrs = dir(user)
pprint.pprint(attrs,compact=True)
# Out:
# ['CHECK_AFTER_INIT_FLAG', '_CompletableGithubObject__complete',
#  '_CompletableGithubObject__completed', '_GithubObject__makeSimpleAttribute',
#  '_GithubObject__makeSimpleListAttribute',
#  '_GithubObject__makeTransformedAttribute', '__annotations__', '__class__',
#  '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__',
#  '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__',
#  '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__',
#  '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__',
#  '__str__', '__subclasshook__', '__weakref__', '_avatar_url', '_bio', '_blog',
#  '_collaborators', '_company', '_completeIfNeeded', '_completeIfNotSet',
#  '_created_at', '_disk_usage', '_email', '_events_url', '_followers',
#  '_followers_url', '_following', '_following_url', '_gists_url', '_gravatar_id',
#  '_headers', '_hireable', '_html_url', '_id', '_initAttributes', '_location',
#  '_login', '_makeBoolAttribute', '_makeClassAttribute',
#  '_makeDatetimeAttribute', '_makeDecimalAttribute', '_makeDictAttribute',
#  '_makeDictOfStringsToClassesAttribute', '_makeFloatAttribute',
#  '_makeHttpDatetimeAttribute', '_makeIntAttribute',
#  '_makeListOfClassesAttribute', '_makeListOfDictsAttribute',
#  '_makeListOfIntsAttribute', '_makeListOfListOfStringsAttribute',
#  '_makeListOfStringsAttribute', '_makeStringAttribute',
#  '_makeTimestampAttribute', '_name', '_node_id', '_organizations_url',
#  '_owned_private_repos', '_parentUrl', '_plan', '_private_gists',
#  '_public_gists', '_public_repos', '_rawData', '_received_events_url',
#  '_repos_url', '_requester', '_site_admin', '_starred_url',
#  '_storeAndUseAttributes', '_subscriptions_url', '_total_private_repos',
#  '_two_factor_authentication', '_type', '_updated_at', '_url', '_useAttributes',
#  'accept_invitation', 'add_to_emails', 'add_to_following', 'add_to_starred',
#  'add_to_subscriptions', 'add_to_watched', 'avatar_url', 'bio', 'blog',
#  'collaborators', 'company', 'create_authorization', 'create_fork',
#  'create_gist', 'create_key', 'create_migration', 'create_project',
#  'create_repo', 'create_repo_from_template', 'created_at', 'disk_usage', 'edit',
#  'email', 'etag', 'events_url', 'followers', 'followers_url', 'following',
#  'following_url', 'get__repr__', 'get_authorization', 'get_authorizations',
#  'get_emails', 'get_events', 'get_followers', 'get_following', 'get_gists',
#  'get_installations', 'get_invitations', 'get_issues', 'get_key', 'get_keys',
#  'get_migrations', 'get_notification', 'get_notifications',
#  'get_organization_events', 'get_organization_membership', 'get_orgs',
#  'get_repo', 'get_repos', 'get_starred', 'get_starred_gists',
#  'get_subscriptions', 'get_teams', 'get_user_issues', 'get_watched',
#  'gists_url', 'gravatar_id', 'has_in_following', 'has_in_starred',
#  'has_in_subscriptions', 'has_in_watched', 'hireable', 'html_url', 'id',
#  'last_modified', 'last_modified_datetime', 'location', 'login',
#  'mark_notifications_as_read', 'name', 'node_id', 'organizations_url',
#  'owned_private_repos', 'plan', 'private_gists', 'public_gists', 'public_repos',
#  'raw_data', 'raw_headers', 'received_events_url', 'remove_from_emails',
#  'remove_from_following', 'remove_from_starred', 'remove_from_subscriptions',
#  'remove_from_watched', 'repos_url', 'setCheckAfterInitFlag', 'site_admin',
#  'starred_url', 'subscriptions_url', 'total_private_repos',
#  'two_factor_authentication', 'type', 'update', 'updated_at', 'url']

# %%
# List all org
data = []
orgs = user.get_orgs()
for org in orgs:
    for member in org.get_members():
        print(member.id, member.name, member.email, member.node_id, member.role)
        # attrs = dir(member)
        # pprint.pprint(attrs,compact=True)
        break
# Out:
# 5167132 Nguyen Thanh Binh None MDQ6VXNlcjUxNjcxMzI= None
# 54620256 None None MDQ6VXNlcjU0NjIwMjU2 None
# 5167132 Nguyen Thanh Binh None MDQ6VXNlcjUxNjcxMzI= None
# 5167132 Nguyen Thanh Binh None MDQ6VXNlcjUxNjcxMzI= None
# 5167132 Nguyen Thanh Binh None MDQ6VXNlcjUxNjcxMzI= None
# 54620256 None None MDQ6VXNlcjU0NjIwMjU2 None

# %%
# List all org
data = []
orgs = user.get_orgs()
for org in orgs:
    for repo in org.get_repos():
        for collaborator in repo.get_collaborators():
            data.append({
                "org": repo.organization.login,
                "repo": repo.name,  
                "user": collaborator.login,
                "triage": collaborator.permissions.triage,
                "push": collaborator.permissions.push, 
                "pull": collaborator.permissions.pull,      
                "maintain": collaborator.permissions.maintain, 
                "admin": collaborator.permissions.admin, 
                "type": collaborator.type
            })
    #         break
    #     break
    # break

# %%
print(data)
# Out:
# [{'org': 'vnpayew', 'repo': 'beagle-backend-kotlin', 'user': 'duhd', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle-backend-kotlin', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle', 'user': 'duhd', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle-backend-ts', 'user': 'duhd', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle-backend-ts', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle-web-react', 'user': 'duhd', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'beagle-web-react', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'openblocks', 'user': 'duhd', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'vnpayew', 'repo': 'openblocks', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'datbeohbbh', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'Hnampk', 'triage': True, 'push': True, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'anhdt-vnpay', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'nguyencongluat', 'triage': True, 'push': True, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'lequocvieet', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'vtf_network', 'user': 'myme89', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'datbeohbbh', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'Hnampk', 'triage': True, 'push': True, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'anhdt-vnpay', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'nguyencongluat', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'lequocvieet', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'sharding_accounting', 'user': 'myme89', 'triage': False, 'push': False, 'pull': True, 'maintain': False, 'admin': False, 'type': 'User'}, {'org': 'blcvn', 'repo': 'new_explorer', 'user': 'binhjax', 'triage': True, 'push': True, 'pull': True, 'maintain': True, 'admin': True, 'type': 'User'}, {'org': 'blcvn', ...

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.1.1-cp310-cp310-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 13.7 MB/s eta 0:00:0000:010:01
# Downloading numpy-2.1.1-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 14.6 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.1.1 pandas-2.2.2 pytz-2024.1 tzdata-2024.1

# %%
# for repo in g.get_user().get_repos():
#     print(repo.full_name)
    # attrs = dir(repo)
    # pprint.pprint(attrs,compact=True)
    # for member in repo.get_members():
    #     attrs = dir(member)
    #     pprint.pprint(attrs,compact=True)
    #     break
    # break
    # print(repo.full_name)
#     break
# # To close connections after use
# g.close()

# %%
import pandas as pd  
df = pd.DataFrame.from_dict(data)

# %%
df.to_csv('blc_vnpay.csv', index=False)

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.5

# %%
df.to_excel("blc_vnpay.xlsx",sheet_name='github')

# %% [markdown]
# # 2.Deleted acccount from github

# %%
selected_repos = [
"blcvn/vtf_network",
"blcvn/sharding_accounting",
"blcvn/k8s_loyalty",
"blcvn/loyalty-lib-go",
"blcvn/loyalty-api",
"blcvn/loyalty-client-app",
"blcvn/lib-golang-test",
"blcvn/loyalty-deploy",
"blcvn/loyalty-crosscheck",
"blcvn/baas_backend",
"blcvn/baas_frontend",
"blcvn/nhs_node",
"blcvn/vtf_web",
"blcvn/vnpoint_node",
"blcvn/vnpoint_network",
"blcvn/nhs_network",
"blcvn/vtf_node",
"blcvn/f5_core",
"blcvn/f5_deploy",
"blcvn/vtf_trace",
"blcvn/f5_wallet",
"blcvn/vtf_explorer",
"blcvn/admin-api",
"blcvn/corev3-api",
"blcvn/corev3-appclient",
"blcvn/corev3-chaincode",
"blcvn/corev3-wallet",
"blcvn/corev3-gstate",
"blcvn/corev3-finalize",
"blcvn/corev3-protos",
"blcvn/corev3-libs",
"blcvn/f5_shard",
"blcvn/tool-check-ewallet",
"blcvn/build-binary",
"blcvn/corev3-account-state",
"blcvn/crosscheck",
"blcvn/corev3-sidechain-client",
"blcvn/osb-protos",
"blcvn/corev3-txmanager",
"blcvn/loyalty-jobs",
"blcvn/corev3-ipn",
"blcvn/throughput-tools",
"blcvn/admin-ui",
"blcvn/web",
"blcvn/migrate-tools",
"blcvn/admin-deploy",
"blcvn/teleport",
"blcvn/osb-deploy",
"blcvn/osb-goal-keeper",
"blcvn/osb-network",
"atn-dao/backend",
"enablelabs-eco/explorer"
]

# %%
account = "sunspirit9999"
for repo in g.get_user().get_repos():
    if repo.full_name in selected_repos:
        print("Check:", repo.full_name)
        deletedAccount = None 
        for collaborator in repo.get_collaborators():
            if collaborator.login == account:
                print("Find: ", collaborator.login, " in repo: ", repo.full_name)
                deletedAccount = collaborator
        if deletedAccount:
            print(" => Delete ", deletedAccount.login, " in repo: ", repo.full_name)
            repo.remove_from_collaborators(deletedAccount)
        # attrs = dir(repo)
        # pprint.pprint(attrs,compact=True)
# Out:
# Check: atn-dao/backend
# Check: blcvn/admin-api
# Find:  sunspirit9999  in repo:  blcvn/admin-api
#  => Delete  sunspirit9999  in repo:  blcvn/admin-api
# Check: blcvn/admin-deploy
# Find:  sunspirit9999  in repo:  blcvn/admin-deploy
#  => Delete  sunspirit9999  in repo:  blcvn/admin-deploy
# Check: blcvn/admin-ui
# Find:  sunspirit9999  in repo:  blcvn/admin-ui
#  => Delete  sunspirit9999  in repo:  blcvn/admin-ui
# Check: blcvn/baas_backend
# Find:  sunspirit9999  in repo:  blcvn/baas_backend
#  => Delete  sunspirit9999  in repo:  blcvn/baas_backend
# Check: blcvn/baas_frontend
# Find:  sunspirit9999  in repo:  blcvn/baas_frontend
#  => Delete  sunspirit9999  in repo:  blcvn/baas_frontend
# Check: blcvn/build-binary
# Find:  sunspirit9999  in repo:  blcvn/build-binary
#  => Delete  sunspirit9999  in repo:  blcvn/build-binary
# Check: blcvn/corev3-account-state
# Find:  sunspirit9999  in repo:  blcvn/corev3-account-state
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-account-state
# Check: blcvn/corev3-api
# Find:  sunspirit9999  in repo:  blcvn/corev3-api
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-api
# Check: blcvn/corev3-appclient
# Find:  sunspirit9999  in repo:  blcvn/corev3-appclient
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-appclient
# Check: blcvn/corev3-chaincode
# Find:  sunspirit9999  in repo:  blcvn/corev3-chaincode
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-chaincode
# Check: blcvn/corev3-finalize
# Find:  sunspirit9999  in repo:  blcvn/corev3-finalize
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-finalize
# Check: blcvn/corev3-gstate
# Find:  sunspirit9999  in repo:  blcvn/corev3-gstate
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-gstate
# Check: blcvn/corev3-ipn
# Find:  sunspirit9999  in repo:  blcvn/corev3-ipn
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-ipn
# Check: blcvn/corev3-libs
# Find:  sunspirit9999  in repo:  blcvn/corev3-libs
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-libs
# Check: blcvn/corev3-protos
# Find:  sunspirit9999  in repo:  blcvn/corev3-protos
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-protos
# Check: blcvn/corev3-sidechain-client
# Find:  sunspirit9999  in repo:  blcvn/corev3-sidechain-client
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-sidechain-client
# Check: blcvn/corev3-txmanager
# Find:  sunspirit9999  in repo:  blcvn/corev3-txmanager
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-txmanager
# Check: blcvn/corev3-wallet
# Find:  sunspirit9999  in repo:  blcvn/corev3-wallet
#  => Delete  sunspirit9999  in repo:  blcvn/corev3-wallet
# Check: blcvn/crosscheck
# Find:  sunspirit9999  in repo:  blcvn/crosscheck
#  => Delete  sunspirit9999  in repo:  blcvn/crosscheck
# Check: blcvn/f5_core
# Find:  sunspirit9999  in repo:  blcvn/f5_core
#  => Delete  sunspirit9999  in repo:  blcvn/f5_core
# Check: blcvn/f5_deploy
# Find:  sunspirit9999  in repo:  blcvn/f5_deploy
#  => Delete  sunspirit9999  in repo:  blcvn/f5_deploy
# Check: blcvn/f5_shard
# Find:  sunspirit9999  in repo:  blcvn/f5_shard
#  => Delete  sunspirit9999  in repo:  blcvn/f5_shard
# Check: blcvn/f5_wallet
# Find:  sunspirit9999  in repo:  blcvn/f5_wallet
#  => Delete  sunspirit9999  in repo:  blcvn/f5_wallet
# Check: blcvn/k8s_loyalty
# Find:  sunspirit9999  in repo:  blcvn/k8s_loyalty
#  => Delete  sunspirit9999  in repo:  blcvn/k8s_loyalty
# Check: blcvn/lib-golang-test
# Find:  sunspirit9999  in repo:  blcvn/lib-golang-test
#  => Delete  sunspirit9999  in repo:  blcvn/lib-golang-test
# Check: blcvn/loyalty-api
# Find:  sunspirit9999  in repo:  blcvn/loyalty-api
#  => Delete  sunspirit9999  in repo:  blcvn/loyalty-api
# Check: blcvn/loyalty-client-app
# Find:  sunspirit9999  in repo:  blcvn/loyalty-client-app
#  => Delete  sunspirit9999  in repo:  blcvn/loyalty-client-app
# Check: blcvn/loyalty-crosscheck
# Find:  sunspirit9999  in repo:  blcvn/loyalty-crosscheck
#  => Delete  sunspirit9999  in repo:  blcvn/loyalty-crosscheck
# Check: blcvn/loyalty-deploy
# Find:  sunspirit9999  in repo:  blcvn/loyalty-deploy
#  => Delete  sunspirit9999  in repo:  blcvn/loyalty-deploy
# Check: blcvn/loyalty-jobs
# Find:  sunspirit9999  in repo:  blcvn/loyalty-jobs
#  => Delete  sunspirit9999  in repo:  blcvn/loyalty-jobs
# Check: blcvn/loyalty-lib-go
# Find:  sunspirit9999  in repo:  blcvn/loyalty-lib-go
#  => Delete  sunspirit9999  in repo:  blcvn/loyalty-lib-go
# Check: blcvn/migrate-tools
# Find:  sunspirit9999  in repo:  blcvn/migrate-tools
#  => Delete  sunspirit9999  in repo:  blcvn/migrate-tools
# Check: blcvn/nhs_network
# Find:  sunspirit9999  in repo:  blcvn/nhs_network
#  => Delete  sunspirit9999  in repo:  blcvn/nhs_network
# Check: blcvn/nhs_node
# Find:  sunspirit9999  in repo:  blcvn/nhs_node
#  => Delete  sunspirit9999  in repo:  blcvn/nhs_node
# Check: blcvn/osb-deploy
# Find:  sunspirit9999  in repo:  blcvn/osb-deploy
#  => Delete  sunspirit9999  in repo:  blcvn/osb-deploy
# Check: blcvn/osb-goal-keeper
# Find:  sunspirit9999  in repo:  blcvn/osb-goal-keeper
#  => Delete  sunspirit9999  in repo:  blcvn/osb-goal-keeper
# Check: blcvn/osb-network
# Find:  sunspirit9999  in repo:  blcvn/osb-network
#  => Delete  sunspirit9999  in repo:  blcvn/osb-network
# Check: blcvn/osb-protos
# Find:  sunspirit9999  in repo:  blcvn/osb-protos
#  => Delete  sunspirit9999  in repo:  blcvn/osb-protos
# Check: blcvn/sharding_accounting
# Find:  sunspirit9999  in repo:  blcvn/sharding_accounting
#  => Delete  sunspirit9999  in repo:  blcvn/sharding_accounting
# Check: blcvn/teleport
# Find:  sunspirit9999  in repo:  blcvn/teleport
#  => Delete  sunspirit9999  in repo:  blcvn/teleport
# Check: blcvn/throughput-tools
# Find:  sunspirit9999  in repo:  blcvn/throughput-tools
#  => Delete  sunspirit9999  in repo:  blcvn/throughput-tools
# Check: blcvn/tool-check-ewallet
# Find:  sunspirit9999  in repo:  blcvn/tool-check-ewallet
#  => Delete  sunspirit9999  in repo:  blcvn/tool-check-ewallet
# Check: blcvn/vnpoint_network
# Find:  sunspirit9999  in repo:  blcvn/vnpoint_network
#  => Delete  sunspirit9999  in repo:  blcvn/vnpoint_network
# Check: blcvn/vnpoint_node
# Find:  sunspirit9999  in repo:  blcvn/vnpoint_node
#  => Delete  sunspirit9999  in repo:  blcvn/vnpoint_node
# Check: blcvn/vtf_explorer
# Find:  sunspirit9999  in repo:  blcvn/vtf_explorer
#  => Delete  sunspirit9999  in repo:  blcvn/vtf_explorer
# Check: blcvn/vtf_network
# Find:  sunspirit9999  in repo:  blcvn/vtf_network
#  => Delete  sunspirit9999  in repo:  blcvn/vtf_network
# Check: blcvn/vtf_node
# Find:  sunspirit9999  in repo:  blcvn/vtf_node
#  => Delete  sunspirit9999  in repo:  blcvn/vtf_node
# Check: blcvn/vtf_trace
# Find:  sunspirit9999  in repo:  blcvn/vtf_trace
#  => Delete  sunspirit9999  in repo:  blcvn/vtf_trace
# Check: blcvn/vtf_web
# Find:  sunspirit9999  in repo:  blcvn/vtf_web
#  => Delete  sunspirit9999  in repo:  blcvn/vtf_web
# Check: blcvn/web
# Find:  sunspirit9999  in repo:  blcvn/web
#  => Delete  sunspirit9999  in repo:  blcvn/web
# Check: enablelabs-eco/explorer
